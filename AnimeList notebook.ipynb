# %%
#import stuff for the project

import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
import numpy as np
import pandas as pd
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report,confusion_matrix

#sklearn stuff importing

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

#read the data- other window

animeFiltered = pd.read_csv(r'C:\Users\\97252\OneDrive\שולחן העבודה\anime_filtered.csv')
animeFiltered .info()
animeFiltered .head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14474 entries, 0 to 14473
# Data columns (total 31 columns):
# anime_id          14474 non-null int64
# title             14474 non-null object
# title_english     5723 non-null object
# title_japanese    14440 non-null object
# title_synonyms    8936 non-null object
# image_url         14378 non-null object
# type              14474 non-null object
# source            14474 non-null object
# episodes          14474 non-null int64
# status            14474 non-null object
# airing            14474 non-null bool
# aired_string      14474 non-null object
# aired             14474 non-null object
# duration          14474 non-null object
# rating            14474 non-null object
# score             14474 non-null float64
# scored_by         14474 non-null int64
# rank              12901 non-null float64
# popularity        14474 non-null int64
# members           14474 non-null int64
# favorites         14474 non-null int64
# ...

# %%
print("The dataset contains following number of records for each of the columns : \n" +str(animeFiltered.count()))
# Out:
# The dataset contains following number of records for each of the columns :
# anime_id          14474
# title             14474
# title_english      5723
# title_japanese    14440
# title_synonyms     8936
# image_url         14378
# type              14474
# source            14474
# episodes          14474
# status            14474
# airing            14474
# aired_string      14474
# aired             14474
# duration          14474
# rating            14474
# score             14474
# scored_by         14474
# rank              12901
# popularity        14474
# members           14474
# favorites         14474
# background         1057
# premiered          4096
# broadcast          4271
# related           14474
# producer           8288
# licensor           3373
# studio             8544
# genre             14410
# opening_theme     14474
# ending_theme      14474
# dtype: int64

# %%
#cleaning the data, let's drop columns which we think do not contribute our mission

a=animeFiltered.drop(['producer'], axis=1)
b=a.drop(['aired'], axis=1)
#animeFiltered.drop(['scored by'], axis=1)
c=b.drop(['related'], axis=1)
d=c.drop(['licensor'], axis=1)
e=d.drop(['ending_theme'], axis=1)
f=e.drop(['opening_theme'], axis=1)
g=f.drop(['aired_string'], axis=1)
h=g.drop(['title_english'], axis=1)
i=h.drop(['title_japanese'], axis=1)
j=i.drop(['anime_id'], axis=1)
k=j.drop(['title'], axis=1)
m=k.drop(['image_url'], axis=1)
n=m.drop(['background'], axis=1)
l=n.drop(['members'], axis=1)
o=l.drop(['title_synonyms'], axis=1)
p=o.drop(['rank'], axis=1)
q=p.drop(['airing'], axis=1)
r=q.drop(['scored_by'], axis=1)
s=r.drop(['favorites'], axis=1)

#maybe drop popularity

clean=s
clean
# Out:
#           type    source  episodes           status         duration  \
# 0           TV     Manga        12  Finished Airing  24 min. per ep.
# 1           TV     Manga        26  Finished Airing  24 min. per ep.
# 2           TV     Manga        51  Finished Airing  24 min. per ep.
# 3           TV  Original        38  Finished Airing  16 min. per ep.
# 4           TV     Manga        25  Finished Airing  24 min. per ep.
# ...        ...       ...       ...              ...              ...
# 14469       TV   Unknown         5  Finished Airing   8 min. per ep.
# 14470      OVA   Unknown         1  Finished Airing          25 min.
# 14471    Movie     Other         1    Not yet aired          Unknown
# 14472      OVA     Other         1  Finished Airing          40 min.
# 14473  Special   Unknown         1  Finished Airing           3 min.
#
#                                rating  score  popularity    premiered  \
# ...

# %%
#Define our mission!
#the aim of this project is to forecast anime's success by it's score.

clean.loc[clean['score'] <7, 'score'] = 0
clean.loc[clean['score'] >= 7, 'score'] = 1

clean
# Out:
#           type    source  episodes           status         duration  \
# 0           TV     Manga        12  Finished Airing  24 min. per ep.
# 1           TV     Manga        26  Finished Airing  24 min. per ep.
# 2           TV     Manga        51  Finished Airing  24 min. per ep.
# 3           TV  Original        38  Finished Airing  16 min. per ep.
# 4           TV     Manga        25  Finished Airing  24 min. per ep.
# ...        ...       ...       ...              ...              ...
# 14469       TV   Unknown         5  Finished Airing   8 min. per ep.
# 14470      OVA   Unknown         1  Finished Airing          25 min.
# 14471    Movie     Other         1    Not yet aired          Unknown
# 14472      OVA     Other         1  Finished Airing          40 min.
# 14473  Special   Unknown         1  Finished Airing           3 min.
#
#                                rating  score  popularity    premiered  \
# ...

# %%
#duriation processing-

clean['duration'] = animeFiltered['duration'].str.replace(r'\D', '')
clean['duration'] = animeFiltered['duration'].str.replace(r'. per ep.', '')
clean['duration'] = clean['duration'].str.replace(r'.', '')

#deal with Unknowns
#get the most common one:
clean.duration #or add

clean.loc[clean['duration'] == 'Unknown', ['duration']] = '24 min'

#covert to timedelta-
clean['duration'] = pd.to_timedelta(clean['duration'])

#timedelta to minutes
clean['duration'] = clean['duration'].dt.total_seconds() / (60)


clean
# Out:
#           type    source  episodes           status  duration  \
# 0           TV     Manga        12  Finished Airing      24.0
# 1           TV     Manga        26  Finished Airing      24.0
# 2           TV     Manga        51  Finished Airing      24.0
# 3           TV  Original        38  Finished Airing      16.0
# 4           TV     Manga        25  Finished Airing      24.0
# ...        ...       ...       ...              ...       ...
# 14469       TV   Unknown         5  Finished Airing       8.0
# 14470      OVA   Unknown         1  Finished Airing      25.0
# 14471    Movie     Other         1    Not yet aired      24.0
# 14472      OVA     Other         1  Finished Airing      40.0
# 14473  Special   Unknown         1  Finished Airing       3.0
#
#                                rating  score  popularity    premiered  \
# 0           PG-13 - Teens 13 or older    1.0         231  Winter 2012
# 1           PG-13 - Teens 13 or older    1.0         366  Spring 2007
# ...

# %%
#premiered proccessing- only the seasons matter to us, dealing with future animes (later years)

clean['premiered'] = clean['premiered'].str.replace('\d+', '')
clean

#get which "premiered" is the most common
clean.premiered.mode()

#fill NaNs with the most common season- spring
clean['premiered']=clean['premiered'].fillna("Spring")

# %%
#duration processing 2-
#because 32/31 mins are the same in our matter, we'll divide the mins for categories:
#0: less than 23-short
#1: 23-45 medium
#2: more than 45- long

clean.loc[clean['duration'] < 23, 'duration'] = 0
clean.loc[clean['duration'] >= 23, 'duration'] = 1
clean.loc[clean['duration'] > 45, 'duration'] = 2

clean
# Out:
#           type    source  episodes           status  duration  \
# 0           TV     Manga        12  Finished Airing       1.0
# 1           TV     Manga        26  Finished Airing       1.0
# 2           TV     Manga        51  Finished Airing       1.0
# 3           TV  Original        38  Finished Airing       0.0
# 4           TV     Manga        25  Finished Airing       1.0
# ...        ...       ...       ...              ...       ...
# 14469       TV   Unknown         5  Finished Airing       0.0
# 14470      OVA   Unknown         1  Finished Airing       1.0
# 14471    Movie     Other         1    Not yet aired       1.0
# 14472      OVA     Other         1  Finished Airing       1.0
# 14473  Special   Unknown         1  Finished Airing       0.0
#
#                                rating  score  popularity premiered  \
# 0           PG-13 - Teens 13 or older    1.0         231   Winter
# 1           PG-13 - Teens 13 or older    1.0         366   Spring
# ...

# %%
#airing time MAYBE processing
#from datetime import datetime

#data = {'from': '2011-02-23', 'to': '2011-04-27'};
#from_date = datetime.strptime(data['from'], '%Y-%m-%d')
#to_date = datetime.strptime(data['to'],'%Y-%m-%d')

#clean['aired'] = animeFiltered['aired'].str.replace(to_date, '')

# %%
clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14474 entries, 0 to 14473
# Data columns (total 12 columns):
# type          14474 non-null object
# source        14474 non-null object
# episodes      14474 non-null int64
# status        14474 non-null object
# duration      14474 non-null float64
# rating        14474 non-null object
# score         14474 non-null float64
# popularity    14474 non-null int64
# premiered     14474 non-null object
# broadcast     4271 non-null object
# studio        8544 non-null object
# genre         14410 non-null object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 1.3+ MB

# %%
clean.dtypes
# Out:
# type           object
# source         object
# episodes        int64
# status         object
# duration      float64
# rating         object
# score         float64
# popularity      int64
# premiered      object
# broadcast      object
# studio         object
# genre          object
# dtype: object

# %% [markdown]
#  # cleaning the data # #

# %%
#cleaning null to spot and fill nulls
#dummies_replacement

obj_df = clean.select_dtypes(include=['object'])
obj_df.head()

#clean
obj_df[obj_df.isnull().any(axis=1)]

obj_df["broadcast"].value_counts #to see which is the most common one, so we'll fill the null ones with it
obj_df = obj_df.fillna({"broadcast": "Unknown"})

obj_df["studio"].value_counts #to see which is the most common one, so we'll fill the null ones with it
obj_df = obj_df.fillna({"studio": "Unknown"})

#get which duration is the most common
clean.duration.mode()
clean['duration']=clean['duration'].replace("Unknown", "24 min")

# %%
#Cat.codes- dummies alternative

obj_df["studio"] = obj_df["studio"].astype('category')
obj_df.dtypes
clean["studio"] = obj_df["studio"].cat.codes

obj_df["genre"] = obj_df["genre"].astype('category')
obj_df.dtypes
clean["genre"] = obj_df["genre"].cat.codes

obj_df["broadcast"] = obj_df["broadcast"].astype('category')
obj_df.dtypes
clean["broadcast"] = obj_df["broadcast"].cat.codes

#obj_df["status"] = obj_df["status"].astype('category')
#obj_df.dtypes
#clean["status"] = obj_df["status"].cat.codes

obj_df["rating"] = obj_df["rating"].astype('category')
obj_df.dtypes
clean["rating"] = obj_df["rating"].cat.codes

#obj_df['duration'] = obj_df['duration'].astype('category')
#obj_df.dtypes
#clean['duration'] = obj_df['duration'].cat.codes

#obj_df["aired"] = obj_df["aired"].astype('category')
#obj_df.dtypes
#clean["aired"] = obj_df["aired"].cat.codes

obj_df["source"] = obj_df["source"].astype('category')
obj_df.dtypes
clean["source"] = obj_df["source"].cat.codes

obj_df["type"] = obj_df["type"].astype('category')
obj_df.dtypes
clean["type"] = obj_df["type"].cat.codes

obj_df["premiered"] = obj_df["premiered"].astype('category')
obj_df.dtypes
clean["premiered"] = obj_df["premiered"].cat.codes

obj_df.info()
#dummies
clean2=pd.get_dummies(clean.status)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14474 entries, 0 to 14473
# Data columns (total 8 columns):
# type         14474 non-null category
# source       14474 non-null category
# status       14474 non-null object
# rating       14474 non-null category
# premiered    14474 non-null category
# broadcast    14474 non-null category
# studio       14474 non-null category
# genre        14410 non-null category
# dtypes: category(7), object(1)
# memory usage: 501.3+ KB

# %%
clean2
# Out:
#        Currently Airing  Finished Airing  Not yet aired
# 0                     0                1              0
# 1                     0                1              0
# 2                     0                1              0
# 3                     0                1              0
# 4                     0                1              0
# ...                 ...              ...            ...
# 14469                 0                1              0
# 14470                 0                1              0
# 14471                 0                0              1
# 14472                 0                1              0
# 14473                 0                1              0
#
# [14474 rows x 3 columns]

# %%
clean=clean2.join(clean)
clean=clean.drop(['status'], axis=1)
clean
# Out:
#        Currently Airing  Finished Airing  Not yet aired  type  source  \
# 0                     0                1              0     5       6
# 1                     0                1              0     5       6
# 2                     0                1              0     5       6
# 3                     0                1              0     5       9
# 4                     0                1              0     5       6
# ...                 ...              ...            ...   ...     ...
# 14469                 0                1              0     5      13
# 14470                 0                1              0     3      13
# 14471                 0                0              1     0      10
# 14472                 0                1              0     3      10
# 14473                 0                1              0     4      13
#
#        episodes  duration  rating  score  popularity  premiered  broadcast  \
# ...

# %%
pd.set_option('display.max_rows', None)
print(clean.premiered)
# Out:
# 0        4
# 1        2
# 2        0
# 3        3
# 4        0
# 5        0
# 6        2
# 7        0
# 8        0
# 9        2
# 10       0
# 11       2
# 12       0
# 13       0
# 14       0
# 15       2
# 16       0
# 17       4
# 18       2
# 19       0
# 20       0
# 21       0
# 22       0
# 23       4
# 24       0
# 25       0
# 26       2
# 27       4
# 28       2
# 29       2
# 30       2
# 31       2
# 32       3
# 33       2
# 34       0
# 35       2
# 36       2
# 37       2
# 38       0
# 39       4
# 40       4
# 41       0
# 42       2
# 43       0
# 44       4
# 45       0
# 46       2
# 47       2
# 48       4
# 49       2
# 50       3
# 51       2
# 52       0
# 53       3
# 54       0
# 55       1
# 56       1
# 57       1
# 58       0
# 59       1
# 60       1
# 61       1
# 62       2
# 63       1
# 64       1
# 65       1
# 66       1
# 67       3
# 68       1
# 69       1
# 70       2
# 71       1
# 72       1
# 73       1
# 74       0
# 75       1
# ...

# %%
clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14474 entries, 0 to 14473
# Data columns (total 14 columns):
# Currently Airing    14474 non-null uint8
# Finished Airing     14474 non-null uint8
# Not yet aired       14474 non-null uint8
# type                14474 non-null int8
# source              14474 non-null int8
# episodes            14474 non-null int64
# duration            14474 non-null float64
# rating              14474 non-null int8
# score               14474 non-null float64
# popularity          14474 non-null int64
# premiered           14474 non-null int8
# broadcast           14474 non-null int16
# studio              14474 non-null int16
# genre               14474 non-null int16
# dtypes: float64(2), int16(3), int64(2), int8(4), uint8(3)
# memory usage: 636.2 KB

# %%
# train_test_split
X_train, X_test, y_train, y_test = train_test_split(clean.drop('score', axis=1), clean['score'], test_size=0.20, random_state=0)

# %%
clean['duration'].max()
# Out:
# 1.0

# %%
clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14474 entries, 0 to 14473
# Data columns (total 14 columns):
# Currently Airing    14474 non-null uint8
# Finished Airing     14474 non-null uint8
# Not yet aired       14474 non-null uint8
# type                14474 non-null int8
# source              14474 non-null int8
# episodes            14474 non-null int64
# duration            14474 non-null float64
# rating              14474 non-null int8
# score               14474 non-null float64
# popularity          14474 non-null int64
# premiered           14474 non-null int8
# broadcast           14474 non-null int16
# studio              14474 non-null int16
# genre               14474 non-null int16
# dtypes: float64(2), int16(3), int64(2), int8(4), uint8(3)
# memory usage: 636.2 KB

# %%
from sklearn.metrics import accuracy_score, log_loss
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

classifiers = [
    KNeighborsClassifier(3),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    AdaBoostClassifier(),
    GradientBoostingClassifier()
    ]
for classifier in classifiers:
    model = classifier.fit(X_train, y_train)
    print("\n The Classifier is \n " +str(classifier))
    print("\n The Model's Score is %.3f" % model.score(X_test, y_test))
    y_pred_best = model.predict(X_test)
    cm=confusion_matrix(y_test, y_pred_best, labels=None, sample_weight=None)
    print(cm)
    print(classification_report(y_test,y_pred_best))
    #sns.heatmap(pd.DataFrame(classification_report).iloc[:-1, :].T, annot=True)
# Out:
#  The Classifier is
#  KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')
#
#  The Model's Score is 0.823
# [[1901  211]
#  [ 300  483]]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.90      0.88      2112
#          1.0       0.70      0.62      0.65       783
#
#     accuracy                           0.82      2895
#    macro avg       0.78      0.76      0.77      2895
# weighted avg       0.82      0.82      0.82      2895
#
#
#  The Classifier is
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
# ...
