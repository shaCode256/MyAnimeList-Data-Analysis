# %%
#Using Matplotlib
from pandas import DataFrame
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
import numpy as np
import pandas as pd
aS = pd.read_csv(r'C:\Users\\97252\OneDrive\שולחן העבודה\AppleStore.csv')
#aS.info()

# %%
#SAVE RESULTS TO

save_results_to = '/Users/97252/OneDrive/שולחן העבודה/AVMadnat/AVMadnat'

# %%
aS.head() #observing ehat we have
# Out:
#    Unnamed: 0                                         track_name  size_bytes  \
# 0           1                                    PAC-MAN Premium   100788224
# 1           2                          Evernote - stay organized   158578688
# 2           3    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3           4  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4           5                                              Bible    92774400
#
#   currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 0      USD   3.99             21292                26          4.0
# 1      USD   0.00            161065                26          4.0
# 2      USD   0.00            188583              2822          3.5
# 3      USD   0.00            262241               649          4.0
# 4      USD   0.00            985920              5320          4.5
#
#    user_rating_ver     ver   prime_genre  sup_devices.num  lang.num
# ...

# %%
#graph 1

#AppleStore.plot(kind='bar',x='prime_genre',y='lang.num',color='blue')
#matplotlib.pyplot.bar(x, height, width=0.8, bottom=None, *, align='center', data=None, **kwargs)
#plt.show()

# %%
#matplot 2

#price distribution of apps

bS = pd.read_csv(r'C:\Users\\97252\OneDrive\שולחן העבודה\AppleStore.csv')
plt.figure(figsize=(10, 10))

axes= bS.price.value_counts().plot(kind='pie')
axes.set_title("Apps' Price$ Distribution", fontsize=20)

axes.set_xlabel("")
axes.set_ylabel("")

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig(save_results_to + 'price distribution of apps.png', dpi = 300)

# %%
#matplot 1

#user ratings' distribution by score

plt.figure(figsize=(10, 10))
axes=aS.user_rating.value_counts().plot(kind='pie')
axes.set_title("User Ratings' Distribution by Score", fontsize=20)
axes.set_xlabel("")
axes.set_ylabel("")

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig(save_results_to + 'user ratings distribution by score.png', dpi = 300)

# %%
aS.prime_genre
# Out:
# 0              Games
# 1       Productivity
# 2            Weather
# 3           Shopping
# 4          Reference
#             ...
# 7192           Games
# 7193           Games
# 7194       Utilities
# 7195           Games
# 7196           Games
# Name: prime_genre, Length: 7197, dtype: object

# %%
#matplot 4.5

#which genre has the highest rating score

AppleStore= aS
games=AppleStore[AppleStore['prime_genre']=='Games']
productivity=AppleStore[AppleStore['prime_genre']=='Productivity']
weather=AppleStore[AppleStore['prime_genre']=='Weather']
shopping=AppleStore[AppleStore['prime_genre']=='Shopping']
News=AppleStore[AppleStore['prime_genre']=='News']
Entertainment =AppleStore[AppleStore['prime_genre']=='Entertainment']
pv=AppleStore[AppleStore['prime_genre']=='Photo & Video']
tvl=AppleStore[AppleStore['prime_genre']=='Travel']
lfs=AppleStore[AppleStore['prime_genre']=='Lifestyle']
bks=AppleStore[AppleStore['prime_genre']=='Book']
utl=AppleStore[AppleStore['prime_genre']=='Utilities']
fns=AppleStore[AppleStore['prime_genre']=='Finance']
mss=AppleStore[AppleStore['prime_genre']=='Music']
sns=AppleStore[AppleStore['prime_genre']=='Socical Networking']
sps=AppleStore[AppleStore['prime_genre']=='Sports']
bss=AppleStore[AppleStore['prime_genre']=='Buisness']
hnf=AppleStore[AppleStore['prime_genre']=='Health & Fitness']
nvg=AppleStore[AppleStore['prime_genre']=='Navigation']
eds=AppleStore[AppleStore['prime_genre']=='Education']
mds=AppleStore[AppleStore['prime_genre']=='Medical']
cts=AppleStore[AppleStore['prime_genre']=='Catalogs']


#df's of genres

gamesMax=games['user_rating'].mean()
pm=productivity['user_rating'].mean()
wh=weather['user_rating'].mean()
sh=shopping['user_rating'].mean()
ns=News['user_rating'].mean()
ed=Entertainment['user_rating'].mean()
pvn=pv['user_rating'].mean()
tv= tvl['user_rating'].mean()
ls= lfs['user_rating'].mean()
bk= bks['user_rating'].mean()
ut= utl['user_rating'].mean()
fn= fns['user_rating'].mean()
ms= mss['user_rating'].mean()
sn= sns['user_rating'].mean()
sp= sps['user_rating'].mean()
bs= bss['user_rating'].mean()
hf= hnf['user_rating'].mean()
nv= nvg['user_rating'].mean()
ed= eds['user_rating'].mean()
md= mds['user_rating'].mean()
ct= cts['user_rating'].mean()


df = pd.DataFrame({'mean of rating': [gamesMax, pm, wh, sh, ns, ed, pvn, tv, ls, bk, ut, fn, ms, sn, sp, bs, hf, nv, ed, md, ct ],
                   'genres': ['Games', 'Productivity' , 'Weather', 'Shopping', 'News','Entertainment', 'Photo & Video', 'Travel','Lifestyle', 'Book', 'Utilities', 'Finance', 'Music', 'Social Networking', 'Sports', 'Buisness', 'Health & Fitness', 'Navigation', 'Education', 'Medical', 'catalogs']})

my_colors = 'red', 'green','blue', 'yellow', 'orange','black','pink','gray','cyan','gold','purple','silver','maroon','teal','wheat','lime','plum','lightsteelblue','indigo','bisque'

axes=df.plot.bar(x='genres', y='mean of rating',figsize=(10, 8), color=my_colors)


axes.set_title("Mean of Rating Score by Genres", fontsize=20)
axes.set_ylabel('Mean of Rating Score ',fontsize=20)
axes.set_xlabel('Genre',fontsize=20)

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig(save_results_to + 'Mean of Rating Score by Genres.png', dpi = 300)

# %%
#matplot 3

#which genre is the priciest

#AppleStore.plot(x='prime_genre',y='price',color='blue')
#plt.show()
AppleStore= aS
games=AppleStore[AppleStore['prime_genre']=='Games']
productivity=AppleStore[AppleStore['prime_genre']=='Productivity']
weather=AppleStore[AppleStore['prime_genre']=='Weather']
shopping=AppleStore[AppleStore['prime_genre']=='Shopping']
News=AppleStore[AppleStore['prime_genre']=='News']
Entertainment =AppleStore[AppleStore['prime_genre']=='Entertainment']
pv=AppleStore[AppleStore['prime_genre']=='Photo & Video']
tvl=AppleStore[AppleStore['prime_genre']=='Travel']
lfs=AppleStore[AppleStore['prime_genre']=='Lifestyle']
bks=AppleStore[AppleStore['prime_genre']=='Book']
utl=AppleStore[AppleStore['prime_genre']=='Utilities']
fns=AppleStore[AppleStore['prime_genre']=='Finance']
mss=AppleStore[AppleStore['prime_genre']=='Music']
sns=AppleStore[AppleStore['prime_genre']=='Socical Networking']
sps=AppleStore[AppleStore['prime_genre']=='Sports']
bss=AppleStore[AppleStore['prime_genre']=='Buisness']
hnf=AppleStore[AppleStore['prime_genre']=='Health & Fitness']
nvg=AppleStore[AppleStore['prime_genre']=='Navigation']
eds=AppleStore[AppleStore['prime_genre']=='Education']
mds=AppleStore[AppleStore['prime_genre']=='Medical']
cts=AppleStore[AppleStore['prime_genre']=='Catalogs']


#df's of genres

gamesMax=games['price'].mean()
pm=productivity['price'].mean()
wh=weather['price'].mean()
sh=shopping['price'].mean()
ns=News['price'].mean()
ed=Entertainment['price'].mean()
pvn=pv['price'].mean()
tv= tvl['price'].mean()
ls= lfs['price'].mean()
bk= bks['price'].mean()
ut= utl['price'].mean()
fn= fns['price'].mean()
ms= mss['price'].mean()
sn= sns['price'].mean()
sp= sps['price'].mean()
bs= bss['price'].mean()
hf= hnf['price'].mean()
nv= nvg['price'].mean()
ed= eds['price'].mean()
md= mds['price'].mean()
ct= cts['price'].mean()


df = pd.DataFrame({'mean Price': [gamesMax, pm, wh, sh, ns, ed, pvn, tv, ls, bk, ut, fn, ms, sn, sp, bs, hf, nv, ed, md, ct ],
                   'genres': ['Games', 'Productivity' , 'Weather', 'Shopping', 'News','Entertainment', 'Photo & Video', 'Travel','Lifestyle', 'Book', 'Utilities', 'Finance', 'Music', 'Socical Networking', 'Sports', 'Buisness', 'Health & Fitness', 'Navigation', 'Education', 'Medical', 'catalogs']})

my_colors = 'red', 'green','blue', 'yellow', 'orange','black','pink','gray','cyan','gold','purple','silver','maroon','teal','wheat','lime','plum','lightsteelblue','indigo','bisque'

axes=df.plot.bar(x='genres', y='mean Price',figsize=(10, 8), color=my_colors)

axes.set_title("Apps' Mean price by genres", fontsize=20)
axes.set_ylabel('Mean Price by $',fontsize=20)
axes.set_xlabel('genre',fontsize=20)

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig(save_results_to + 'Apps Mean price by genres.png', dpi = 300)

# %%
#matplot 4

#which genre people tend to rate the most

AppleStore= aS
games=AppleStore[AppleStore['prime_genre']=='Games']
productivity=AppleStore[AppleStore['prime_genre']=='Productivity']
weather=AppleStore[AppleStore['prime_genre']=='Weather']
shopping=AppleStore[AppleStore['prime_genre']=='Shopping']
News=AppleStore[AppleStore['prime_genre']=='News']
Entertainment =AppleStore[AppleStore['prime_genre']=='Entertainment']
pv=AppleStore[AppleStore['prime_genre']=='Photo & Video']
tvl=AppleStore[AppleStore['prime_genre']=='Travel']
lfs=AppleStore[AppleStore['prime_genre']=='Lifestyle']
bks=AppleStore[AppleStore['prime_genre']=='Book']
utl=AppleStore[AppleStore['prime_genre']=='Utilities']
fns=AppleStore[AppleStore['prime_genre']=='Finance']
mss=AppleStore[AppleStore['prime_genre']=='Music']
sns=AppleStore[AppleStore['prime_genre']=='Socical Networking']
sps=AppleStore[AppleStore['prime_genre']=='Sports']
bss=AppleStore[AppleStore['prime_genre']=='Buisness']
hnf=AppleStore[AppleStore['prime_genre']=='Health & Fitness']
nvg=AppleStore[AppleStore['prime_genre']=='Navigation']
eds=AppleStore[AppleStore['prime_genre']=='Education']
mds=AppleStore[AppleStore['prime_genre']=='Medical']
cts=AppleStore[AppleStore['prime_genre']=='Catalogs']


#df's of genres

gamesMax=games['rating_count_tot'].mean()
pm=productivity['rating_count_tot'].mean()
wh=weather['rating_count_tot'].mean()
sh=shopping['rating_count_tot'].mean()
ns=News['rating_count_tot'].mean()
ed=Entertainment['rating_count_tot'].mean()
pvn=pv['rating_count_tot'].mean()
tv= tvl['rating_count_tot'].mean()
ls= lfs['rating_count_tot'].mean()
bk= bks['rating_count_tot'].mean()
ut= utl['rating_count_tot'].mean()
fn= fns['rating_count_tot'].mean()
ms= mss['rating_count_tot'].mean()
sn= sns['rating_count_tot'].mean()
sp= sps['rating_count_tot'].mean()
bs= bss['rating_count_tot'].mean()
hf= hnf['rating_count_tot'].mean()
nv= nvg['rating_count_tot'].mean()
ed= eds['rating_count_tot'].mean()
md= mds['rating_count_tot'].mean()
ct= cts['rating_count_tot'].mean()


df = pd.DataFrame({'mean of rating count tots': [gamesMax, pm, wh, sh, ns, ed, pvn, tv, ls, bk, ut, fn, ms, sn, sp, bs, hf, nv, ed, md, ct ],
                   'genres': ['Games', 'Productivity' , 'Weather', 'Shopping', 'News','Entertainment', 'Photo & Video', 'Travel','Lifestyle', 'Book', 'Utilities', 'Finance', 'Music', 'Social Networking', 'Sports', 'Buisness', 'Health & Fitness', 'Navigation', 'Education', 'Medical', 'catalogs']})

my_colors = 'red', 'green','blue', 'yellow', 'orange','black','pink','gray','cyan','gold','purple','silver','maroon','teal','wheat','lime','plum','lightsteelblue','indigo','bisque'

axes=df.plot.bar(x='genres', y='mean of rating count tots',figsize=(10, 8), color=my_colors)


axes.set_title("Mean of Rating Apps Count by Genres", fontsize=20)
axes.set_ylabel('Mean of Rating Count',fontsize=20)
axes.set_xlabel('Genre',fontsize=20)

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig(save_results_to + 'Mean of Rating Apps Count by Genres.png', dpi = 300)

# %%
#matplot 5

plt.figure(figsize=(10, 10))
aS.price
axes=plt.scatter(aS.user_rating, aS.price)
axes.set_color('yellow')

plt.title('Apps user Rating by price Distribution',fontsize=25)
plt.ylabel('Price by $',fontsize=20)
plt.xlabel(' User Rating ',fontsize=20)

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig(save_results_to + 'Apps user Rating by price Distribution.png', dpi = 300)

# %%
#top 15 most rated apps

AppleStoreByData = aS.sort_values('rating_count_tot', ascending=False)
TopTenRating = AppleStoreByData[:15]

TopTenRating
# Out:
#       Unnamed: 0                           track_name  size_bytes currency  \
# 16            17                             Facebook   389879808      USD
# 519          591                            Instagram   113954816      USD
# 1346        1561                       Clash of Clans   116476928      USD
# 707          810                           Temple Run    65921024      USD
# 7              8              Pandora - Music & Radio   130242560      USD
# 755          863                            Pinterest    74778624      USD
# 4              5                                Bible    92774400      USD
# 1493        1731                     Candy Crush Saga   222846976      USD
# 178          202                        Spotify Music   132510720      USD
# 275          310                          Angry Birds   175966208      USD
# 1246        1450                       Subway Surfers   156038144      USD
# ...

# %%
#top 20 highest rated apps

AppleStoreByData = aS.sort_values('user_rating', ascending=False)
TopTenRating = AppleStoreByData[:20]


TopTenRating
# Out:
#       Unnamed: 0                                         track_name  \
# 7196       11097                       Escape the Sweet Shop Series
# 6231        8904                           激おこ!! はじめしゃちょー　なんなんですか!?
# 2531        2991                                         Mini Metro
# 2530        2990  Wayfair - Shop Furniture, Home Decor, Daily Sales
# 4885        6343  Mystic Castle - the Simplest & Best RPG and Ad...
# 843          959               CCW – Concealed Carry 50 State Guide
# 6253        8949  PS Deals+ - Games Price Alerts for PS4, PS3, Vita
# 850          967                               驴妈妈旅游-订景点门票机票火车票特价酒店
# 3672        4476            Productive habits & daily goals tracker
# 855          973                              Daily Audio Bible App
# 3389        4096    Flight Pilot Simulator 3D: Flying Game For Free
# 4202        5260   Speedafari – Speed Up Safari on Slow Connections
# 3384        4087                                      ごちうさアラーム～チノ編～
# ...

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
AppleStore = pd.read_csv(r'C:\Users\\97252\OneDrive\שולחן העבודה\AppleStore.csv')

# %%
#Using Seaborn
import seaborn as sns

# %%
#Number of apps by genres
#1 sns

sns.set(font_scale=1.3)  # crazy big

plt.figure(figsize=(10, 10))

axes = sns.countplot(y=AppleStore.prime_genre)

csfont = {'fontname':'Comic Sans MS'}

axes.set_title("Apps quantity by genres",**csfont,fontsize=25)
axes.set_ylabel('genre',fontsize=20,**csfont)
axes.set_xlabel(' Number of Apps ',fontsize=20,**csfont)

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig(save_results_to + 'Number of apps by genres.png', dpi = 300)

# %%
#Number of apps by categories
#2 sns

sns.set(font_scale=1.3)  # crazy big

plt.figure(figsize=(10, 10))

axes = sns.countplot(y=AppleStore.price)

csfont = {'fontname':'Comic Sans MS'}

axes.set_title("price Distribution of Apps",**csfont,fontsize=25)
axes.set_ylabel('Price by $',fontsize=20,**csfont)
axes.set_xlabel(' Number of Apps ',fontsize=20,**csfont)

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig(save_results_to + 'Number of apps by categories.png', dpi = 300)

# %%
#3 sns

#lang.num distrbution by prime genres

g = sns.catplot(x="lang.num", y="prime_genre",
                data=aS, kind="strip",
                height=20, aspect=.7);
g.fig.suptitle('Language num by genres', y=1)

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig(save_results_to + 'lang.num distrbution by prime genres.png', dpi = 300)

# %%
#4 sns

#Apps' Price Distribution by Genres

sns.set(font_scale=1.3)  # crazy big

plt.figure(figsize=(15,10))

axes = sns.stripplot(x="price", y="prime_genre", data=aS)
csfont = {'fontname':'Comic Sans MS'}

axes.set_title("Apps' Price Distribution by Genres",**csfont,fontsize=25)
axes.set_ylabel('Genre',fontsize=20,**csfont)
axes.set_xlabel(' Price $ ',fontsize=20,**csfont)


###############################how to save the graphs as a file#####################
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig(save_results_to + 'Apps Price Distribution by Genres.png', dpi = 300)

# %%
#flights = aS.pivot("prime_genre", "price", "user_rating")
#ax = sns.heatmap(flights)
#aS.info()

# %%
#5 sns

#Pairplot of games

games=AppleStore[AppleStore['prime_genre']=='Games']

#pairplot of free games

freeGames=games[games['price']==0]

plotFree = sns.pairplot(freeGames)

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig(save_results_to + 'Pairplot of free games.png', dpi = 300)

# %%
#6 sns

#Pairplot of paid games

paidGames=games[games['price']!='0']

plotPaid = sns.pairplot(paidGames)
plotPaid

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig(save_results_to + 'Pairplot of paid games.png', dpi = 300)
# Out:
# C:\Users\97252\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
#bonusUNMOVAN- sns100

g = sns.catplot(x="user_rating", y="prime_genre",
                data=aS, kind="strip",
                height=20, aspect=.7);
g.fig.suptitle('user rating of Apps by genres', y=1)

#shows that there isn't a real connection between price&score

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig(save_results_to + 'sns user rating of Apps by genres.png', dpi = 300)

# %%
#bonus- sns7

g = sns.catplot(x="user_rating", y="price",
                data=aS, kind="strip",
                height=20, aspect=.7);
g.fig.suptitle('user rating of Apps by price', y=1)

#shows that there isn't a real connection between price&score

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig(save_results_to + 'sns user rating of Apps by price.png', dpi = 300)

# %%
#matplot 6

#shows there's no actual connection 
#for app developers- let them no they have no reason to deal with these factors (only)-
#while wanting to gain better rating score.

fig,axs = plt.subplots(3,figsize=(15,15))
#f = plt.figure(figsize=(10,3))
#ax = f.add_subplot(121)
plt.figure(figsize=(10, 10))

fig.suptitle("Games' Features VS Rating Score",size=25)
#ax = f.add_subplot(121)
#ax2 = f.add_subplot(122)
axs[0].plot(games.price, games.user_rating)
axs[0].set_xlabel("Price $")
axs[0].set_ylabel("User Rating")

axs[1].plot(games.rating_count_tot, games.user_rating)
axs[1].set_xlabel("Rating Count")
axs[1].set_ylabel("User Rating")
#axs[1].set_color("green")

axs[2].plot(games.ver, games.user_rating)
axs[2].set_xlabel("Version of App")
axs[2].set_ylabel("User Rating")
#axs[2].set_color("red")

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig(save_results_to + 'Games price, num. of rates and lang num. compares to rating score.png', dpi = 300)

#axs[2].plot(games.(lang.num), games.user_rating)
#axs[3].plot(games.sup_devidata:image/png;base64,...ces.num, games.user_rating)
